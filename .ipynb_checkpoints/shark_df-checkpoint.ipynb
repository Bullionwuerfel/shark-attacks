# %% [markdown]
# # Shark Data Frame | Importing & Creating

# %%
import pandas as pd

# %%
import re # Import ReGex module

# %%
url='https://www.sharkattackfile.net/spreadsheets/GSAF5.xls'

# %%
shark_df=pd.read_excel(url)

# %% [markdown]
# # Shark Data Frame | Cleaning

# %%
# drop all rowsthat have no values
shark_df = shark_df.dropna(how='all')

# %%
# Fixes error in "Species " column name.
shark_df.rename(columns={"Species ": "Species"}, inplace = True)

# %%
# Changing column name to a simplified version
shark_df.rename(columns={"Fatal Y/N": "Fatal"}, inplace=True)

# %%
# Dropping unnecessary columns
shark_df.drop(['Unnamed: 22',
               'Unnamed: 21',
               'original order',
               'Case Number.1',
               'href',
               'href formula',
               'pdf',
               'Case Number'
              ], axis=1, inplace=True)

# %%
# Changing Column "Type" entries: Provoked (2 --> 1) & Questionable (2 --> 1) & Unverified =
shark_df["Type"]=shark_df["Type"].apply(lambda t: "Provoked" if t==" Provoked" else "Questionable" if t=="?" else  t)

# %%
# Changing Column "Type" entries: Unverified = Unconfirmed, Invalid, Under investigation, Questionable & Watercraft = Boat
shark_df["Type"]=shark_df["Type"].apply(lambda t: "Watercraft" if t=="Boat" else "Unverified" if t=="Unconfirmed" else "Unverified" if t=="Invalid" else "Unverified" if t=="Under investigation" else "Unverified" if t=="Questionable" else t)

# %%
# Changing Column "Fatal" entries: unifying yes and no.
shark_df["Fatal"]=shark_df["Fatal"].apply(lambda f: True if f=="F" else False if f=="n" else False if f==" N" else False if f=="N " else False if f=="Nq" else True if f=="y" else True if f=="Y x 2" else False if f=="M" else f)

# %%
shark_df["Fatal"]=shark_df["Fatal"].apply(lambda f: True if f=="Y" else False if f=="N" else False)

# %% [markdown]
# # Shark Data Frame | Species Dataframe

# %%
species_df = shark_df.dropna(subset=['Species'])

# %%
def map_species(value):
        if 'white' in value.lower():
            return 'white'
        elif 'tiger' in value.lower():
            return 'tiger'
        elif 'bull' in value.lower():
            return 'bull'
        else:
            return 'none'

# %%
species_df['Species'] = species_df['Species'].apply(map_species)
# Out:
# /var/folders/0d/nrxf3dnx3jq4b9fj3db32zgr0000gn/T/ipykernel_22724/3255184783.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   species_df['Species'] = species_df['Species'].apply(map_species)

# %%
species_df.reset_index(drop = True)
# Out:
#                      Date    Year        Type        Country  \
# 0     2025-01-11 00:00:00  2025.0    Provoked            USA
# 1     2025-01-02 00:00:00  2025.0  Unprovoked  New Caledonia
# 2     2025-01-02 00:00:00  2025.0  Unprovoked      Australia
# 3     2024-12-29 00:00:00  2024.0  Unprovoked          Egypt
# 4     2024-12-29 00:00:00  2024.0  Unprovoked          Egypt
# ...                   ...     ...         ...            ...
# 3853          Early 1930s     0.0  Unprovoked         BELIZE
# 3854          Before 1906     0.0  Unprovoked      AUSTRALIA
# 3855          Before 1906     0.0  Unprovoked      AUSTRALIA
# 3856          Before 1906     0.0  Unprovoked      AUSTRALIA
# 3857          Before 1906     0.0  Unprovoked      AUSTRALIA
#
#                     State                                 Location  \
# 0                  Hawaii            Off Haleiwa Boat Harbour Oahu
# 1            Grande Terre              Islet of Kendek near Koumac
# 2         South Australia  Granites Beach near Westall Streaky Bay
# 3     North of Marsa Alam                                  Red Sea
# 4     North of Marsa Alam                                  Red Sea
# ...                   ...                                      ...
# 3853                  NaN                                      NaN
# 3854                  NaN                                      NaN
# 3855                  NaN                                      NaN
# 3856                  NaN                                      NaN
# 3857      New South Wales
#
#           Activity                                    Name Sex  Age  \
# 0           Diving  Male not stated was a dive tour worker   M   23
# 1     Spearfishing                        Robert Cuewapuru   M   40
# 2          Surfing                           Lance Appleby   M   28
# 3     SCUBA Diving                         Peppino Fappani   M   69
# 4     SCUBA Diving                       Gianluca Di Gioia   M   48
# ...            ...                                     ...  ..  ...
# 3853      Standing                               a servant   M   16
# 3854       Fishing                                     boy   M  NaN
# 3855       Fishing                               fisherman   M  NaN
# 3856       Fishing                               fisherman   M  NaN
# 3857      Swimming                                Arab boy   M  NaN
#
#                                                  Injury  Fatal     Time  \
# 0                                     Bitten on the arm  False  1340hrs
# 1     Severe arm injury and delay in medical treatme...   True   1615hr
# 2                                    Body not recovered   True   1710hr
# 3       Injuries to stomach preventing attack on friend  False        ?
# 4     Entire calf muscle removed and bitten both arm...   True        ?
# ...                                                 ...    ...      ...
# 3853                                              FATAL   True      NaN
# 3854  FATAL, knocked overboard by tail of shark & ca...   True      NaN
# 3855                                              FATAL   True      NaN
# 3856                                              FATAL   True      NaN
# 3857                                              FATAL   True      NaN
#
#      Species                                             Source
# 0       none                  Kevin McMurray Trackingsharks.com
# 1      tiger                      Johannes Marchand Todd Smith
# 2      white  Glen Folkard: Simon De Marchi News.com.au: The...
# 3      tiger  Todd Smith : Kevin McMurray Trackingsharks .co...
# 4      tiger  Todd Smith : Kevin McMurray Trackingsharks .co...
# ...      ...                                                ...
# 3853   tiger                                    Mitchell-Hedges
# 3854    none  NY Sun, 9/9/1906, referring to account by Loui...
# 3855    none  NY Sun, 9/9/1906, referring to account by Loui...
# 3856    none  NY Sun, 9/9/1906, referring to account by Loui...
# 3857    none  L. Becke in New York Sun, 9/9/1906; L. Schultz...
#
# [3858 rows x 15 columns]

# %%
species_df.rename(columns={"Type": "Total"}, inplace = True)
# Out:
# /var/folders/0d/nrxf3dnx3jq4b9fj3db32zgr0000gn/T/ipykernel_22724/1778397923.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   species_df.rename(columns={"Type": "Total"}, inplace = True)

# %%
total_attacks_group = species_df.groupby('Species')[['Total']].count().reset_index()

# %%
total_attacks_group
# Out:
#   Species  Total
# 0    bull    222
# 1    none   2546
# 2   tiger    337
# 3   white    746

# %%
species_df["Species"].value_counts()
# Out:
# Species
# none     2552
# white     746
# tiger     337
# bull      223
# Name: count, dtype: int64

# %%
fatal_filter = species_df[(species_df['Species'] != 'none') & (species_df['Fatal'] == True)]

# %%
fatal_none = species_df[(species_df['Species'] == 'none') & (species_df['Fatal'] == True)]

# %%
other_species_fatal = fatal_none.groupby("Species")[['Fatal']].count().reset_index()

# %%
other_species_fatal
# Out:
#   Species  Fatal
# 0    none    175

# %%
fatal_attacks = fatal_filter.groupby("Species")["Fatal"].count()

# %%
fatal_attacks
# Out:
# Species
# bull      40
# tiger     84
# white    173
# Name: Fatal, dtype: int64

# %%
fatal_attacks.sum()
# Out:
# 297

# %%
total_filter = species_df[(species_df["Species"] != "none")]

# %%
total_attacks_fatal = fatal_filter.groupby("Species")[["Fatal"]].count().reset_index()

# %%
total_attacks_fatal
# Out:
#   Species  Fatal
# 0    bull     40
# 1   tiger     84
# 2   white    173

# %%
other_species_fatal
# Out:
#   Species  Fatal
# 0    none    175

# %%
total_attacks_group
# Out:
#   Species  Total
# 0    bull    222
# 1    none   2546
# 2   tiger    337
# 3   white    746

# %%
all_fatal_attacks = pd.concat([total_attacks_fatal, other_species_fatal], axis=0) 
all_fatal_attacks
# Out:
#   Species  Fatal
# 0    bull     40
# 1   tiger     84
# 2   white    173
# 0    none    175

# %%
total_vs_fatal = pd.merge(total_attacks_group, all_fatal_attacks, on='Species', how='right')
total_vs_fatal
# Out:
#   Species  Total  Fatal
# 0    bull    222     40
# 1   tiger    337     84
# 2   white    746    173
# 3    none   2546    175

# %%
total_vs_fatal['Percentage_fatal'] = (total_vs_fatal['Fatal']*100 // total_vs_fatal['Total']) 
total_vs_fatal
# Out:
#   Species  Total  Fatal  Percentage_fatal
# 0    bull    222     40                18
# 1   tiger    337     84                24
# 2   white    746    173                23
# 3    none   2546    175                 6

# %% [markdown]
# # Shark Data Frame | Time Dataframe

# %%
shark_df["Type"].unique()
# Out:
# array(['Provoked', 'Unprovoked', 'Unverified', 'Watercraft',
#        'Sea Disaster', nan], dtype=object)

# %%
shark_df["Fatal"].unique()
# Out:
# array([False,  True])

# %%
shark_df["Fatal"].unique()
# Out:
# array([False,  True])

# %%
shark_df["Time"].unique()
# Out:
# array(['1340hrs', '1615hr', '1710hr', '?', '1637hr', 'AM', '16.30hrs',
#        '1600hr', '11.30hr', '1100hr', '1735hr', '11hr15', '16hr15',
#        'after 1200hr', '1400hr', 15.5, '13h15', '9h', 1300, '14h',
#        '15h30', 'Not stated', '13h30', '9h15', 'Not advised', '13h40',
#        '12h30', '16h00', nan, '11h30', '06h30', '20h00', '13h00', '11h12',
#        '16h30', '15h00', '02h00', '09h15', 'Early Morning', '16h32',
#        '11h00', 'Morning', '10h30', '13h20', '14h00', '09h00', '10h20',
#        '15h05', '17h00', '15h45', '07h45', '10h40', '07h50', '01h00',
#        '10h00', 'Afternoon', '19h30', 'Evening', '17h50', '09h30',
#        '08h45', '"Midday"', '16h25', '13h55', '13h50', '17h20', '13h45',
#        '10h10', '14h35', 'Night', '1500h ', '19h15', '11h20', '07h15',
#        '07h00', '18h00', '08h00', '14h20', '17h30', '07h20', '14h50',
#        '-16h30', '12h00', '17h17', '11h15', '19h00', '07h53', '16h10',
#        '11h17', '17h45', '10jh45', 'Early  morning', '13h12', '07h30',
#        '11hoo', '11h43', '10h15', '14h09', '12h15', '19h12', '15h20',
#        '16h40', '11h24', '12h50', '07h31', '14h45', '19h20', 'Dusk',
#        '11h45', '06h40', '`17h00', '07h51', '11h46', '20h30', '12h23',
#        '07h07', '16h39', '15h57', '14h30', '16h45', '10j30', '08h15',
#        '08h56', '15h40', '18h30', '07h58', '17h40', '09h00-10h00',
#        '17h10', '09h36', '08h40', '06h00', 'Sunset', '10h45', 1415,
#        '14h00-15h00', '14h15', '09h08', '15h59', '08h30', '12h20',
#        '10h50', 'Midday', '09h40', '14h33', '12h58', '"Evening"', '16h15',
#        '23h00', '06h50', '12h45', '11h55', '22h20', '08h48', '16h21',
#        '16h26', '18h45', '03h00', '06h15', 'Before 10h00', '06h45',
#        'Early afternoon', '06h55', '13h42', '09h29', '10h47', '14h11',
#        '15h35', '14h40', '14h00  -15h00', 'Late afternoon', '16h50',
#        '21h50', '17h35', '19h00, Dusk', '15h01', 1000, '23h30', '10h44',
#        '13h19', 'Shortly before 12h00', '17h34', '08h50', '09h50', '9h00',
#        '10h43', 'After noon', '15h15', '19h05', '14h30 / 15h30', '22h00',
#        '16h20', '14h34', '15h25', '14h55', '17h46', 'Morning ', '15h49',
#        'Midnight', '09h30 / 10h00', '18h15', '04h00', '10h25',
#        '10h45-11h15', '15h52', '19h45', '12h10', '18h05', '11h41',
#        '12h25', '17h51', '16h12', '09h45', '05h00', '03h30',
#        'Sometime between 06h00 & 08hoo', '16h18', '11h10',
#        '07h00 - 08h00', '18h15-18h30', '17h01', '09h57', '08h20', '17h58',
#        '15h19', '10h55', '15h55', '12h40', '16h05', '14h10', '13h24',
#        '09h00 - 09h30', '0830', '11h40', '08h10', '15h56',
#        'Just before noon', '07h56', '1600', '16h35', '09h05', '19h28',
#        '12h38', '05h50', '15h50', '11h05', 'Early morning', 'Dawn',
#        '05h45', '13h25', '13h26', '09h11', '18h20', '13h51', 'A.M.',
#        '08h05', '10h35', '15h44', '21h00', 'Lunchtime', '15j45', '09h35',
#        '10h27', '10h16', '0500', 'Before 07h00', '09h20',
#        '10h00 -- 11h00', '12h05', '14h21', '18h50', '15h53',
#        '"Just before 11h00"', '11h115', '20h15', '12h39', '07h05', '  ',
#        '13h05', 'N', '11h50', 'Just before sundown', '17h55', '22h30',
#        '17h15', '11h30 ', '06h10', 'Between 05h00 and 08h00', '07h08',
#        '17h00 or 17h40', '>08h00', '--', '12h02', '12h55', '16h14',
#        '17h11', '00h30', '14h37', '10h07', '13h53', '13h23',
#        'Just after 12h00', '02h30', '11h56', ' ',
#        'Shortly after midnight', '14h25', '13h345', '\xa0 ', '06h47',
#        '09h00 -10h00', '20h45 (Sunset)', 'Late morning', 'P.M.', '18h40',
#        '13h14', '13h06', 'Shortly before 13h00', '12h34', '11h53',
#        '8:04 pm', '12h46', '12h48', '17h42', '12h35',
#        'Possibly same incident as 2000.08.21', 'After Dusk', '11h57',
#        'Noon', '11h25', '18h25', '10h28', '14h16', '09h55',
#        '2 hours after Opperman', '09h30 ', 'Mid afternoon', 'Mid morning',
#        '11h48', '11h00 / 11h30', '07h19', '13h37', '11h06', '"Night"',
#        '18h30?', '11h58', '11h51', '18h12', '07h10', '07h40', '12h33',
#        '30 minutes after 1992.07.08.a', '>06h45', '15h06', '12h54',
#        'Between 06h00 & 07h20', '16h55', '05h40', '<07h30', '21h30',
#        '17h00 Sunset', 'Nightfall', 'X', '08h57', '18h30 (Sunset)',
#        '06j00', '08h35', '10h22', '02h45', 'Prior to 10h37', 'Daybreak',
#        '18h10', '>12h00', 'Mid-morning', '08h55', '16h30 or 18h00',
#        'Just before dawn', ' 14h00', 'Daytime', 'Dark', '10h00 / 11h00',
#        '"After lunch"', '07h32', '15h00 or 15h45', '>17h00',
#        '19h00 / 20h00', '12h45 / 13h45', '14h00 - 15h00', 'night',
#        '03h45 - 04h00', '13h10', '09h30 / 15h30', '08h00 / 09h30',
#        '19h35', '12h00 to 14h00', '13h35', 'Late night', '01h32',
#        '10h30 or 13h30', '16h23', '15h00j', 'Midday.', '"After dark"',
#        '10h00 or 14h00', '19h10', '2 hrs before sunset', '18h15 to 21h30',
#        1500, '"shortly before dusk"', '>17h30', '>14h30',
#        'Between 11h00 & 12h00', 'After 04h00',
#        '11h01 -time of ship sinking', 'Ship aban-doned at 03h10', '19h55',
#        'After dusk',
#        'FATAL  (Wire netting installed at local beaches after this incident.)',
#        '01h30', 'After midnight', 'Late afternon', '05h30', '08h58',
#        '"Early evening"', 'Late Afternoon', '   ', 'Before daybreak',
#        'dusk', 'Before 10h30', '06h00 -- 07h00', '01h50', '17h00-18h00',
#        '19h00-20h00'], dtype=object)

# %%
shark_df.dtypes
# Out:
# Date         object
# Year        float64
# Type         object
# Country      object
# State        object
# Location     object
# Activity     object
# Name         object
# Sex          object
# Age          object
# Injury       object
# Fatal          bool
# Time         object
# Species      object
# Source       object
# dtype: object

# %%
shark_df['Date']=pd.to_datetime(shark_df['Date'], infer_datetime_format=True, errors="ignore")
# Out:
# /var/folders/0d/nrxf3dnx3jq4b9fj3db32zgr0000gn/T/ipykernel_22724/4075989833.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   shark_df['Date']=pd.to_datetime(shark_df['Date'], infer_datetime_format=True, errors="ignore")
# /var/folders/0d/nrxf3dnx3jq4b9fj3db32zgr0000gn/T/ipykernel_22724/4075989833.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   shark_df['Date']=pd.to_datetime(shark_df['Date'], infer_datetime_format=True, errors="ignore")

# %%
shark_df
# Out:
#                      Date    Year        Type             Country  \
# 0     2025-01-11 00:00:00  2025.0    Provoked                 USA
# 1     2025-01-02 00:00:00  2025.0  Unprovoked       New Caledonia
# 2     2025-01-02 00:00:00  2025.0  Unprovoked           Australia
# 3     2024-12-29 00:00:00  2024.0  Unprovoked               Egypt
# 4     2024-12-29 00:00:00  2024.0  Unprovoked               Egypt
# ...                   ...     ...         ...                 ...
# 6985          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6986          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6987            1900-1905     0.0  Unprovoked                 USA
# 6988            1883-1889     0.0  Unprovoked              PANAMA
# 6989            1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                     State                                 Location  \
# 0                  Hawaii            Off Haleiwa Boat Harbour Oahu
# 1            Grande Terre              Islet of Kendek near Koumac
# 2         South Australia  Granites Beach near Westall Streaky Bay
# 3     North of Marsa Alam                                  Red Sea
# 4     North of Marsa Alam                                  Red Sea
# ...                   ...                                      ...
# 6985    Western Australia                              Roebuck Bay
# 6986    Western Australia                                      NaN
# 6987       North Carolina                           Ocracoke Inlet
# 6988                  NaN                     Panama Bay 8ºN, 79ºW
# 6989     Eastern Province      Below the English fort, Trincomalee
#
#           Activity                                    Name Sex  Age  \
# 0           Diving  Male not stated was a dive tour worker   M   23
# 1     Spearfishing                        Robert Cuewapuru   M   40
# 2          Surfing                           Lance Appleby   M   28
# 3     SCUBA Diving                         Peppino Fappani   M   69
# 4     SCUBA Diving                       Gianluca Di Gioia   M   48
# ...            ...                                     ...  ..  ...
# 6985        Diving                                    male   M  NaN
# 6986  Pearl diving                                   Ahmun   M  NaN
# 6987      Swimming                   Coast Guard personnel   M  NaN
# 6988           NaN                         Jules Patterson   M  NaN
# 6989      Swimming                                    male   M   15
#
#                                                  Injury  Fatal     Time  \
# 0                                     Bitten on the arm  False  1340hrs
# 1     Severe arm injury and delay in medical treatme...   True   1615hr
# 2                                    Body not recovered   True   1710hr
# 3       Injuries to stomach preventing attack on friend  False        ?
# 4     Entire calf muscle removed and bitten both arm...   True        ?
# ...                                                 ...    ...      ...
# 6985                                              FATAL   True      NaN
# 6986                                              FATAL   True      NaN
# 6987                                              FATAL   True      NaN
# 6988                                              FATAL   True      NaN
# 6989  FATAL. "Shark bit him in half, carrying away t...   True      NaN
#
#                                      Species  \
# 0                                 Not stated
# 1             Reportedly Tiger or Bull shark
# 2     Great White Shart estimated 4.8m 16 ft
# 3                   Reportedly a Tiger Shark
# 4                   Reportedly a Tiger Shark
# ...                                      ...
# 6985                                     NaN
# 6986                                     NaN
# 6987                                     NaN
# 6988                                     NaN
# 6989                                     NaN
#
#                                                  Source
# 0                     Kevin McMurray Trackingsharks.com
# 1                         Johannes Marchand Todd Smith
# 2     Glen Folkard: Simon De Marchi News.com.au: The...
# 3     Todd Smith : Kevin McMurray Trackingsharks .co...
# 4     Todd Smith : Kevin McMurray Trackingsharks .co...
# ...                                                 ...
# 6985                   H. Taunton; N. Bartlett,  p. 234
# 6986              H. Taunton; N. Bartlett,  pp. 233-234
# 6987               F. Schwartz, p.23; C. Creswell, GSAF
# 6988                                The Sun, 10/20/1938
# 6989                                         S.W. Baker
#
# [6990 rows x 15 columns]

# %%
shark_df['Time']=pd.to_datetime(shark_df['Time'], infer_datetime_format=True, errors="ignore")
# Out:
# /var/folders/0d/nrxf3dnx3jq4b9fj3db32zgr0000gn/T/ipykernel_22724/2084303734.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   shark_df['Time']=pd.to_datetime(shark_df['Time'], infer_datetime_format=True, errors="ignore")
# /var/folders/0d/nrxf3dnx3jq4b9fj3db32zgr0000gn/T/ipykernel_22724/2084303734.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   shark_df['Time']=pd.to_datetime(shark_df['Time'], infer_datetime_format=True, errors="ignore")
# /var/folders/0d/nrxf3dnx3jq4b9fj3db32zgr0000gn/T/ipykernel_22724/2084303734.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   shark_df['Time']=pd.to_datetime(shark_df['Time'], infer_datetime_format=True, errors="ignore")

# %%
shark_df["Time"].value_counts()
# Out:
# Time
# Afternoon      215
# 11h00          140
# Morning        135
# 15h00          127
# 16h00          123
#               ...
# 15h56            1
# 07h56            1
# 09h05            1
# 19h28            1
# 19h00-20h00      1
# Name: count, Length: 432, dtype: int64

# %%
# Ensure Pandas does not truncate large outputs
pd.set_option('display.max_rows', None)  # No limit on rows
pd.set_option('display.max_columns', None)  # No limit on columns

# %%
# Assuming your DataFrame is df and the column is 'column_name'
unique_values = shark_df['Time'].unique()
unique_values
# Out:
# array(['1340hrs', '1615hr', '1710hr', '?', '1637hr', 'AM', '16.30hrs',
#        '1600hr', '11.30hr', '1100hr', '1735hr', '11hr15', '16hr15',
#        'after 1200hr', '1400hr', 15.5, '13h15', '9h', 1300, '14h',
#        '15h30', 'Not stated', '13h30', '9h15', 'Not advised', '13h40',
#        '12h30', '16h00', nan, '11h30', '06h30', '20h00', '13h00', '11h12',
#        '16h30', '15h00', '02h00', '09h15', 'Early Morning', '16h32',
#        '11h00', 'Morning', '10h30', '13h20', '14h00', '09h00', '10h20',
#        '15h05', '17h00', '15h45', '07h45', '10h40', '07h50', '01h00',
#        '10h00', 'Afternoon', '19h30', 'Evening', '17h50', '09h30',
#        '08h45', '"Midday"', '16h25', '13h55', '13h50', '17h20', '13h45',
#        '10h10', '14h35', 'Night', '1500h ', '19h15', '11h20', '07h15',
#        '07h00', '18h00', '08h00', '14h20', '17h30', '07h20', '14h50',
#        '-16h30', '12h00', '17h17', '11h15', '19h00', '07h53', '16h10',
#        '11h17', '17h45', '10jh45', 'Early  morning', '13h12', '07h30',
#        '11hoo', '11h43', '10h15', '14h09', '12h15', '19h12', '15h20',
#        '16h40', '11h24', '12h50', '07h31', '14h45', '19h20', 'Dusk',
#        '11h45', '06h40', '`17h00', '07h51', '11h46', '20h30', '12h23',
#        '07h07', '16h39', '15h57', '14h30', '16h45', '10j30', '08h15',
#        '08h56', '15h40', '18h30', '07h58', '17h40', '09h00-10h00',
#        '17h10', '09h36', '08h40', '06h00', 'Sunset', '10h45', 1415,
#        '14h00-15h00', '14h15', '09h08', '15h59', '08h30', '12h20',
#        '10h50', 'Midday', '09h40', '14h33', '12h58', '"Evening"', '16h15',
#        '23h00', '06h50', '12h45', '11h55', '22h20', '08h48', '16h21',
#        '16h26', '18h45', '03h00', '06h15', 'Before 10h00', '06h45',
#        'Early afternoon', '06h55', '13h42', '09h29', '10h47', '14h11',
#        '15h35', '14h40', '14h00  -15h00', 'Late afternoon', '16h50',
#        '21h50', '17h35', '19h00, Dusk', '15h01', 1000, '23h30', '10h44',
#        '13h19', 'Shortly before 12h00', '17h34', '08h50', '09h50', '9h00',
#        '10h43', 'After noon', '15h15', '19h05', '14h30 / 15h30', '22h00',
#        '16h20', '14h34', '15h25', '14h55', '17h46', 'Morning ', '15h49',
#        'Midnight', '09h30 / 10h00', '18h15', '04h00', '10h25',
#        '10h45-11h15', '15h52', '19h45', '12h10', '18h05', '11h41',
#        '12h25', '17h51', '16h12', '09h45', '05h00', '03h30',
#        'Sometime between 06h00 & 08hoo', '16h18', '11h10',
#        '07h00 - 08h00', '18h15-18h30', '17h01', '09h57', '08h20', '17h58',
#        '15h19', '10h55', '15h55', '12h40', '16h05', '14h10', '13h24',
#        '09h00 - 09h30', '0830', '11h40', '08h10', '15h56',
#        'Just before noon', '07h56', '1600', '16h35', '09h05', '19h28',
#        '12h38', '05h50', '15h50', '11h05', 'Early morning', 'Dawn',
#        '05h45', '13h25', '13h26', '09h11', '18h20', '13h51', 'A.M.',
#        '08h05', '10h35', '15h44', '21h00', 'Lunchtime', '15j45', '09h35',
#        '10h27', '10h16', '0500', 'Before 07h00', '09h20',
#        '10h00 -- 11h00', '12h05', '14h21', '18h50', '15h53',
#        '"Just before 11h00"', '11h115', '20h15', '12h39', '07h05', '  ',
#        '13h05', 'N', '11h50', 'Just before sundown', '17h55', '22h30',
#        '17h15', '11h30 ', '06h10', 'Between 05h00 and 08h00', '07h08',
#        '17h00 or 17h40', '>08h00', '--', '12h02', '12h55', '16h14',
#        '17h11', '00h30', '14h37', '10h07', '13h53', '13h23',
#        'Just after 12h00', '02h30', '11h56', ' ',
#        'Shortly after midnight', '14h25', '13h345', '\xa0 ', '06h47',
#        '09h00 -10h00', '20h45 (Sunset)', 'Late morning', 'P.M.', '18h40',
#        '13h14', '13h06', 'Shortly before 13h00', '12h34', '11h53',
#        '8:04 pm', '12h46', '12h48', '17h42', '12h35',
#        'Possibly same incident as 2000.08.21', 'After Dusk', '11h57',
#        'Noon', '11h25', '18h25', '10h28', '14h16', '09h55',
#        '2 hours after Opperman', '09h30 ', 'Mid afternoon', 'Mid morning',
#        '11h48', '11h00 / 11h30', '07h19', '13h37', '11h06', '"Night"',
#        '18h30?', '11h58', '11h51', '18h12', '07h10', '07h40', '12h33',
#        '30 minutes after 1992.07.08.a', '>06h45', '15h06', '12h54',
#        'Between 06h00 & 07h20', '16h55', '05h40', '<07h30', '21h30',
#        '17h00 Sunset', 'Nightfall', 'X', '08h57', '18h30 (Sunset)',
#        '06j00', '08h35', '10h22', '02h45', 'Prior to 10h37', 'Daybreak',
#        '18h10', '>12h00', 'Mid-morning', '08h55', '16h30 or 18h00',
#        'Just before dawn', ' 14h00', 'Daytime', 'Dark', '10h00 / 11h00',
#        '"After lunch"', '07h32', '15h00 or 15h45', '>17h00',
#        '19h00 / 20h00', '12h45 / 13h45', '14h00 - 15h00', 'night',
#        '03h45 - 04h00', '13h10', '09h30 / 15h30', '08h00 / 09h30',
#        '19h35', '12h00 to 14h00', '13h35', 'Late night', '01h32',
#        '10h30 or 13h30', '16h23', '15h00j', 'Midday.', '"After dark"',
#        '10h00 or 14h00', '19h10', '2 hrs before sunset', '18h15 to 21h30',
#        1500, '"shortly before dusk"', '>17h30', '>14h30',
#        'Between 11h00 & 12h00', 'After 04h00',
#        '11h01 -time of ship sinking', 'Ship aban-doned at 03h10', '19h55',
#        'After dusk',
#        'FATAL  (Wire netting installed at local beaches after this incident.)',
#        '01h30', 'After midnight', 'Late afternon', '05h30', '08h58',
#        '"Early evening"', 'Late Afternoon', '   ', 'Before daybreak',
#        'dusk', 'Before 10h30', '06h00 -- 07h00', '01h50', '17h00-18h00',
#        '19h00-20h00'], dtype=object)

# %%
# new time values
time_dict = {
    '1340hrs': '13:40',
    '1615hr': '16:15',
    '1710hr': '17:10',
    '?': '00:00',  # Assuming placeholder time
    '1637hr': '16:37',
    'AM': '00:00',  # Assuming as AM (midnight)
    '16.30hrs': '16:30',
    '1600hr': '16:00',
    '11.30hr': '11:30',
    '1100hr': '11:00',
    '1735hr': '17:35',
    '11hr15': '11:15',
    '16hr15': '16:15',
    'after 1200hr': '12:00',
    '1400hr': '14:00',
    '15.5': '15:30',  # Interpreted as 15:30
    '13h15': '13:15',
    '9h': '09:00',
    '1300': '13:00',
    '14h': '14:00',
    '15h30': '15:30',
    'Not stated': '00:00',  # Placeholder for unspecified time
    '13h30': '13:30',
    '9h15': '09:15',
    'Not advised': '00:00',  # Placeholder for unspecified time
    '13h40': '13:40',
    '12h30': '12:30',
    '16h00': '16:00',
    'nan': '00:00',  # Placeholder for NaN
    '11h30': '11:30',
    '06h30': '06:30',
    '20h00': '20:00',
    '13h00': '13:00',
    '11h12': '11:12',
    '16h30': '16:30',
    '15h00': '15:00',
    '02h00': '02:00',
    '09h15': '09:15',
    'Early Morning': '05:00',  # Interpreted as early morning
    '16h32': '16:32',
    '11h00': '11:00',
    'Morning': '06:00',  # Interpreted as morning
    '10h30': '10:30',
    '13h20': '13:20',
    '14h00': '14:00',
    '09h00': '09:00',
    '10h20': '10:20',
    '15h05': '15:05',
    '17h00': '17:00',
    '15h45': '15:45',
    '07h45': '07:45',
    '10h40': '10:40',
    '07h50': '07:50',
    '01h00': '01:00',
    '10h00': '10:00',
    'Afternoon': '12:00',  # Interpreted as afternoon
    '19h30': '19:30',
    'Evening': '18:00',  # Interpreted as evening
    '17h50': '17:50',
    '09h30': '09:30',
    '08h45': '08:45',
    '"Midday"': '12:00',
    '16h25': '16:25',
    '13h55': '13:55',
    '13h50': '13:50',
    '17h20': '17:20',
    '13h45': '13:45',
    '10h10': '10:10',
    '14h35': '14:35',
    'Night': '00:00',  # Placeholder for night
    '1500h ': '15:00',
    '19h15': '19:15',
    '11h20': '11:20',
    '07h15': '07:15',
    '07h00': '07:00',
    '18h00': '18:00',
    '08h00': '08:00',
    '14h20': '14:20',
    '17h30': '17:30',
    '07h20': '07:20',
    '14h50': '14:50',
    '-16h30': '16:30',
    '12h00': '12:00',
    '17h17': '17:17',
    '11h15': '11:15',
    '19h00': '19:00',
    '07h53': '07:53',
    '16h10': '16:10',
    '11h17': '11:17',
    '17h45': '17:45',
    '10jh45': '10:45',
    'Early  morning': '05:00',  # Interpreted as early morning
    '13h12': '13:12',
    '07h30': '07:30',
    '11hoo': '11:00',  # Interpreted as typo for 11:00
    '11h43': '11:43',
    '10h15': '10:15',
    '14h09': '14:09',
    '12h15': '12:15',
    '19h12': '19:12',
    '15h20': '15:20',
    '16h40': '16:40',
    '11h24': '11:24',
    '12h50': '12:50',
    '07h31': '07:31',
    '14h45': '14:45',
    '19h20': '19:20',
    'Dusk': '18:00',  # Interpreted as dusk
    '11h45': '11:45',
    '06h40': '06:40',
    '`17h00': '17:00',
    '07h51': '07:51',
    '11h46': '11:46',
    '20h30': '20:30',
    '12h23': '12:23',
    '07h07': '07:07',
    '16h39': '16:39',
    '15h57': '15:57',
    '14h30': '14:30',
    '16h45': '16:45',
    '10j30': '10:30',
    '08h15': '08:15',
    '08h56': '08:56',
    '15h40': '15:40',
    '18h30': '18:30',
    '07h58': '07:58',
    '17h40': '17:40',
    '09h00-10h00': '09:30',  # Approximation
    '17h10': '17:10',
    '09h36': '09:36',
    '08h40': '08:40',
    '06h00': '06:00',
    'Sunset': '18:00',  # Interpreted as sunset
    '10h45': '10:45',
    '1415': '14:15',
    '14h00-15h00': '14:30',  # Approximation
    '14h15': '14:15',
    '09h08': '09:08',
    '15h59': '15:59',
    '08h30': '08:30',
    '12h20': '12:20',
    '10h50': '10:50',
    'Midday': '12:00',
    '09h40': '09:40',
    '14h33': '14:33',
    '12h58': '12:58',
    '"Evening"': '18:00',
    '16h15': '16:15',
    '23h00': '23:00',
    '06h50': '06:50',
    '12h45': '12:45',
    '11h55': '11:55',
    '22h20': '22:20',
    '08h48': '08:48',
    '16h21': '16:21',
    '16h26': '16:26',
    '18h45': '18:45',
    '03h00': '03:00',
    '06h15': '06:15',
    'Before 10h00': '09:00',
    '06h45': '06:45',
    'Early afternoon': '13:00',
    '06h55': '06:55',
    '13h42': '13:42',
    '09h29': '09:29',
    '10h47': '10:47',
    '14h11': '14:11',
    '15h35': '15:35',
    '14h40': '14:40',
    '14h00  -15h00': '14:30',  # Approximation
    'Late afternoon': '16:00',  # Interpreted as late afternoon
    '16h50': '16:50',
    '21h50': '21:50',
    '17h35': '17:35',
    '19h00, Dusk': '19:00',  # Assuming dusk is around 19:00
    '15h01': '15:01',
    '1000': '10:00',
    '23h30': '23:30',
    '10h44': '10:44',
    '13h19': '13:19',
    'Shortly before 12h00': '11:30',  # Interpreted as shortly before noon
    '17h34': '17:34',
    '08h50': '08:50',
    '09h50': '09:50',
    '9h00': '09:00',
    '10h43': '10:43',
    'After noon': '12:00',  # Interpreted as after noon
    '15h15': '15:15',
    '19h05': '19:05',
    '14h30 / 15h30': '15:00',  # Approximation
    '22h00': '22:00',
    '16h20': '16:20',
    '14h34': '14:34',
    '15h25': '15:25',
    '14h55': '14:55',
    '17h46': '17:46',
    'Morning ': '06:00',  # Interpreted as morning
    '15h49': '15:49',
    'Midnight': '00:00',
    '09h30 / 10h00': '09:45',  # Approximation
    '18h15': '18:15',
    '04h00': '04:00',
    '10h25': '10:25',
    '10h45-11h15': '10:45',
    '15h52': '15:52',
    '19h45': '19:45',
    '12h10': '12:10',
    '18h05': '18:05',
    '11h41': '11:41',
    '12h25': '12:25',
    '17h51': '17:51',
    '16h12': '16:12',
    '09h45': '09:45',
    '05h00': '05:00',
    '03h30': '03:30',
    'Sometime between 06h00 & 08hoo': '07:00',  # Approximation
    '16h18': '16:18',
    '11h10': '11:10',
    '07h00 - 08h00': '07:30',  # Approximation
    '18h15-18h30': '18:22',  # Approximation
    '17h01': '17:01',
    '09h57': '09:57',
    '08h20': '08:20',
    '17h58': '17:58',
    '15h19': '15:19',
    '10h55': '10:55',
    '15h55': '15:55',
    '12h40': '12:40',
    '16h05': '16:05',
    '14h10': '14:10',
    '13h24': '13:24',
    '09h00 - 09h30': '09:15',  # Approximation
    '0830': '08:30',
    '11h40': '11:40',
    '08h10': '08:10',
    '15h56': '15:56',
    'Just before noon': '11:30',  # Interpreted as shortly before noon
    '07h56': '07:56',
    '1600': '16:00',
    '16h35': '16:35',
    '09h05': '09:05',
    '19h28': '19:28',
    '12h38': '12:38',
    '05h50': '05:50',
    '15h50': '15:50',
    '11h05': '11:05',
    'Early morning': '05:00',  # Interpreted as early morning
    'Dawn': '05:00',
    '05h45': '05:45',
    '13h25': '13:25',
    '13h26': '13:26',
    '09h11': '09:11',
    '18h20': '18:20',
    '13h51': '13:51',
    'A.M.': '00:00',  # Assuming A.M. (midnight)
    '08h05': '08:05',
    '10h35': '10:35',
    '15h44': '15:44',
    '21h00': '21:00',
    'Lunchtime': '12:00',  # Interpreted as lunchtime
    '15j45': '15:45',  # Typo for 15:45
    '09h35': '09:35',
    '10h27': '10:27',
    '10h16': '10:16',
    '0500': '05:00',
    'Before 07h00': '06:30',  # Interpreted as before 7:00
    '09h20': '09:20',
    '10h00 -- 11h00': '10:30',  # Approximation
    '12h05': '12:05',
    '14h21': '14:21',
    '18h50': '18:50',
    '15h53': '15:53',
    '"Just before 11h00"': '10:45',  # Approximation
    '11h115': '11:15',  # Typo for 11:15
    '20h15': '20:15',
    '12h39': '12:39',
    '07h05': '07:05',
    '  ': '00:00',  # Placeholder for empty space
    '13h05': '13:05',
    'N': '00:00',  # Placeholder for "N"
    '11h50': '11:50',
    'Just before sundown': '18:00',  # Approximation for sundown
    '17h55': '17:55',
    '22h30': '22:30',
    '17h15': '17:15',
    '11h30 ': '11:30',
    '06h10': '06:10',
    'Between 05h00 and 08h00': '06:30',  # Approximation
    '07h08': '07:08',
    '17h00 or 17h40': '17:20',  # Approximation
    '>08h00': '08:00',
    '--': '00:00',  # Placeholder for '--'
    '12h02': '12:02',
    '12h55': '12:55',
    '16h14': '16:14',
    '17h11': '17:11',
    '00h30': '00:30',
    '14h37': '14:37',
    '10h07': '10:07',
    '13h53': '13:53',
    '13h23': '13:23',
    'Just after 12h00': '12:05',
    '02h30': '02:30',
    '11h56': '11:56',
    ' ': '00:00',  # Placeholder for empty space
    'Shortly after midnight': '00:30',  # Approximation
    '14h25': '14:25',
    '13h345': '13:35',  # Typo for 13:35
    '\xa0 ': '00:00',  # Placeholder for special character
    '06h47': '06:47',
    '09h00 -10h00': '09:30',  # Approximation
    '20h45 (Sunset)': '20:45',  # Interpreted as sunset
    'Late morning': '10:00',  # Interpreted as late morning
    'P.M.': '12:00',  # Interpreted as P.M. (noon)
    '18h40': '18:40',
    '13h14': '13:14',
    '13h06': '13:06',
    'Shortly before 13h00': '12:45',  # Approximation
    '12h34': '12:34',
    '11h53': '11:53',
    '8:04 pm': '20:04',  # PM time converted
    '12h46': '12:46',
    '12h48': '12:48',
    '17h42': '17:42',
    '12h35': '12:35',
    'Possibly same incident as 2000.08.21': '00:00',  # Placeholder for unclear context
    'After Dusk': '18:00',  # Approximation for after dusk
    '11h57': '11:57',
    'Noon': '12:00',
    '11h25': '11:25',
    '18h25': '18:25',
    '10h28': '10:28',
    '14h16': '14:16',
    '09h55': '09:55',
    '2 hours after Opperman': '00:00',  # Placeholder for unclear context
    '09h30 ': '09:30',
    'Mid afternoon': '15:00',  # Interpreted as mid-afternoon
    'Mid morning': '09:00',  # Interpreted as mid-morning
    '11h48': '11:48',
    '11h00 / 11h30': '11:15',  # Approximation
    '07h19': '07:19',
    '13h37': '13:37',
    '11h06': '11:06',
    '"Night"': '00:00',  # Placeholder for "Night"
    '18h30?': '18:30',
    '11h58': '11:58',
    '11h51': '11:51',
    '18h12': '18:12',
    '07h10': '07:10',
    '07h40': '07:40',
    '12h33': '12:33',
    '30 minutes after 1992.07.08.a': '00:00',  # Placeholder for unclear context
    '>06h45': '06:45',
    '15h06': '15:06',
    '12h54': '12:54',
    'Between 06h00 & 07h20': '06:40',  # Approximation
    '16h55': '16:55',
    '05h40': '05:40',
    '<07h30': '07:00',  # Interpreted as before 7:30
    '21h30': '21:30',
    '17h00 Sunset': '17:00',  # Interpreted as sunset
    'Nightfall': '00:00',  # Placeholder for nightfall
    'X': '00:00',  # Placeholder for 'X'
    '08h57': '08:57',
    '18h30 (Sunset)': '18:30',  # Interpreted as sunset
    '06j00': '06:00',  # Typo for 06:00
    '08h35': '08:35',
    '10h22': '10:22',
    '02h45': '02:45',
    'Prior to 10h37': '10:00',  # Interpreted as prior to 10:37
    'Daybreak': '05:00',  # Interpreted as daybreak
    '18h10': '18:10',
    '>12h00': '12:00',  # Placeholder for after noon
    'Mid-morning': '09:00',  # Interpreted as mid-morning
    '08h55': '08:55',
    '16h30 or 18h00': '17:15',  # Approximation
    'Just before dawn': '05:00',  # Interpreted as just before dawn
    ' 14h00': '14:00',
    'Daytime': '12:00',  # Interpreted as daytime
    'Dark': '00:00',  # Placeholder for dark
    '10h00 / 11h00': '10:30',  # Approximation
    '"After lunch"': '14:00',  # Interpreted as after lunch
    '07h32': '07:32',
    '15h00 or 15h45': '15:23',  # Approximation
    '>17h00': '17:00',
    '19h00 / 20h00': '19:30',  # Approximation
    '12h45 / 13h45': '13:15',  # Approximation
    '14h00 - 15h00': '14:30',  # Approximation
    'night': '00:00',  # Placeholder for "night"
    '03h45 - 04h00': '03:52',  # Approximation
    '13h10': '13:10',
    '09h30 / 15h30': '12:30',  # Approximation
    '08h00 / 09h30': '08:45',  # Approximation
    '19h35': '19:35',
    '12h00 to 14h00': '13:00',  # Approximation
    '13h35': '13:35',
    'Late night': '00:00',  # Placeholder for late night
    '01h32': '01:32',
    '10h30 or 13h30': '12:00',  # Approximation
    '16h23': '16:23',
    '15h00j': '15:00',  # Typo for 15:00
    'Midday.': '12:00',
    '"After dark"': '18:00',  # Interpreted as after dark
    '10h00 or 14h00': '12:00',  # Approximation
    '19h10': '19:10',
    '2 hrs before sunset': '17:00',  # Approximation
    '18h15 to 21h30': '19:00',  # Approximation
    '1500': '15:00',
    '"shortly before dusk"': '18:00',  # Approximation for dusk
    '>17h30': '17:30',
    '>14h30': '14:30',
    'Between 11h00 & 12h00': '11:30',  # Approximation
    'After 04h00': '04:30',
    '11h01 -time of ship sinking': '00:00',  # Placeholder for unclear context
    'Ship abandoned at 03h10': '03:10',  # Exact time provided
    '19h55': '19:55',
    'After dusk': '18:00',  # Approximation for after dusk
    'FATAL  (Wire netting installed at local beaches after this incident.)': '00:00',  # Placeholder for unclear context
    '01h30': '01:30',
    'After midnight': '00:30',
    'Late afternoon': '16:00',  # Interpreted as late afternoon
    '05h30': '05:30',
    '08h58': '08:58',
    '"Early evening"': '18:00',  # Interpreted as early evening
    'Late Afternoon': '16:30',  # Interpreted as late afternoon
    '   ': '00:00',  # Placeholder for empty space
    'Before daybreak': '05:00',  # Interpreted as before daybreak
    'dusk': '18:00',  # Interpreted as dusk
    'Before 10h30': '10:00',  # Interpreted as before 10:30
    '06h00 -- 07h00': '06:30',  # Approximation
    '01h50': '01:50',
    '17h00-18h00': '17:30',  # Approximation
    '19h00-20h00': '19:30'  # Approximation
}

# %%
# new column with cleaned time added to list
shark_df['clean_time'] = shark_df['Time'].map(time_dict)

# %%
shark_df.head()
# Out:
#                   Date    Year        Type        Country  \
# 0  2025-01-11 00:00:00  2025.0    Provoked            USA
# 1  2025-01-02 00:00:00  2025.0  Unprovoked  New Caledonia
# 2  2025-01-02 00:00:00  2025.0  Unprovoked      Australia
# 3  2024-12-29 00:00:00  2024.0  Unprovoked          Egypt
# 4  2024-12-29 00:00:00  2024.0  Unprovoked          Egypt
#
#                  State                                 Location      Activity  \
# 0               Hawaii            Off Haleiwa Boat Harbour Oahu        Diving
# 1         Grande Terre              Islet of Kendek near Koumac  Spearfishing
# 2      South Australia  Granites Beach near Westall Streaky Bay       Surfing
# 3  North of Marsa Alam                                  Red Sea  SCUBA Diving
# 4  North of Marsa Alam                                  Red Sea  SCUBA Diving
#
#                                      Name Sex Age  \
# 0  Male not stated was a dive tour worker   M  23
# 1                        Robert Cuewapuru   M  40
# 2                           Lance Appleby   M  28
# 3                         Peppino Fappani   M  69
# 4                       Gianluca Di Gioia   M  48
#
#                                               Injury  Fatal     Time  \
# 0                                  Bitten on the arm  False  1340hrs
# 1  Severe arm injury and delay in medical treatme...   True   1615hr
# 2                                 Body not recovered   True   1710hr
# 3    Injuries to stomach preventing attack on friend  False        ?
# 4  Entire calf muscle removed and bitten both arm...   True        ?
#
#                                   Species  \
# 0                              Not stated
# 1          Reportedly Tiger or Bull shark
# 2  Great White Shart estimated 4.8m 16 ft
# 3                Reportedly a Tiger Shark
# 4                Reportedly a Tiger Shark
#
#                                               Source clean_time
# 0                  Kevin McMurray Trackingsharks.com      13:40
# 1                      Johannes Marchand Todd Smith       16:15
# 2  Glen Folkard: Simon De Marchi News.com.au: The...      17:10
# 3  Todd Smith : Kevin McMurray Trackingsharks .co...      00:00
# 4  Todd Smith : Kevin McMurray Trackingsharks .co...      00:00

# %%
# New column "time group" with three categories: morninh, afternoon, night
shark_df['time_group']=shark_df['clean_time'].apply(lambda x: "morning" if (str(x) > '05:59') and (str(x) < '12:01') else ("afternoon" if (str(x) > '12:00') and (str(x) < '18:01') else "night"))

# %%
# time group output
shark_df.groupby('time_group').size()
# Out:
# time_group
# afternoon    1610
# morning      1465
# night        3915
# dtype: int64

# %%
# New Table time group vs. species vs. fatality
shark_time_eval=shark_df.pivot_table(index='time_group', columns='Species ', values=['Fatal'], aggfunc='sum')

# %%
shark_time_eval
# Out:
#            Fatal                                                             \
# Species                "gummy" shark (Rhizoprionodon or Loxodon) 1.2 m [4']
# time_group
# afternoon    0.0  NaN                                                NaN
# morning      0.0  NaN                                                NaN
# night        0.0  0.0                                                0.0
#
#                                                     \
# Species     1.5 m [5'] dusky shark  6' to 8' shark
# time_group
# afternoon                      NaN             0.0
# morning                        0.0             NaN
# night                          NaN             NaN
#
#                                                                            \
# Species     Blacktip shark, C. maculipinnis. 1.9 m to 2.1 m [6.5' to 7']
# time_group
# afternoon                                                 0.0
# morning                                                   NaN
# night                                                     NaN
#
#                                                                   \
# Species     Bull shark, 1.2m   Bull shark, 2.5 m  Bull shark, 5'
# time_group
# afternoon                 NaN                NaN             NaN
# morning                   NaN                0.0             0.0
# night                     0.0                NaN             NaN
#
#                                                  \
# Species     Bull shark, 8'  Galapagos shark, 6'
# time_group
# afternoon              NaN                  NaN
# morning                0.0                  NaN
# night                  NaN                  0.0
#
#                                                                \
# Species     Grey nurse shark,  3 m [10']   Lemon shark, 3.5 m
# time_group
# afternoon                             NaN                 NaN
# morning                               NaN                 NaN
# night                                 0.0                 0.0
#
#                                                             \
# Species     Raggedtooth shark, 2m  Sandbar shark, 3' to 4'
# time_group
# afternoon                     NaN                      0.0
# morning                       0.0                      NaN
# night                         NaN                      NaN
#
#                                                                \
# Species     Sevengill  shark, 1.2 m [4']   Spinner shark, 4'?
# time_group
# afternoon                             0.0                 0.0
# morning                               NaN                 NaN
# night                                 NaN                 NaN
#
#                                                                         \
# Species     Tawney nurse shark, 1m  Tiger shark, 2.8m  Tiger shark, 3'
# time_group
# afternoon                      NaN                NaN              NaN
# morning                        NaN                0.0              NaN
# night                          0.0                NaN              0.0
#
#                                                                           \
# Species     White shark  White shark, 7'   Wobbegong shark, 1.6 to 1.8m
# time_group
# afternoon           NaN               NaN                            NaN
# morning             NaN               0.0                            NaN
# night               0.0               NaN                            0.0
#
#                                                                 \
# Species     a small shark  reef shark, 1.8m  white shark, 15'
# time_group
# afternoon             NaN               NaN                NaN
# morning               NaN               NaN                0.0
# night                 0.0               0.0                NaN
#
#                                                                          \
# Species    "A 2' (0.6 m) brown shark" "A long thin brown-colored shark"
# time_group
# afternoon                         NaN                               NaN
# morning                           NaN                               0.0
# night                             0.0                               NaN
#
#                                                                     \
# Species    "A pack of 6 sharks" "A pack of sharks" "A small shark"
# time_group
# afternoon                   NaN                NaN             0.0
# morning                     NaN                NaN             0.0
# night                       0.0                0.0             0.0
#
#                                                                \
# Species    "Attacked by a number of sharks" "Blue nose shark"
# time_group
# afternoon                               NaN               NaN
# morning                                 NaN               NaN
# night                                   0.0               0.0
#
#                                                                       \
# Species    "Blue nose sharks" "Blue whaler" (Galeolamna) "Dog shark"
# time_group
# afternoon                 NaN                        NaN         NaN
# morning                   NaN                        NaN         NaN
# night                     0.0                        0.0         0.0
#
#                                                                              \
# Species    "Reef shark" "Shark caught later" "Shark had a very large girth"
# time_group
# afternoon           NaN                  NaN                            0.0
# morning             NaN                  NaN                            NaN
# night               0.0                  0.0                            NaN
#
#                                                                                                                                               \
# Species    "The fish was harpooned, dried, and presented to the sailor, who went round Europe exhibiting it  It was said to be 20 feet long.
# time_group
# afternoon                                                 NaN
# morning                                                   NaN
# night                                                     0.0
#
#                                                                 \
# Species    "a black-tipped shark" "a blue shark" "a dog shark"
# time_group
# afternoon                     NaN            NaN           NaN
# morning                       NaN            NaN           NaN
# night                         0.0            0.0           0.0
#
#                                                                   \
# Species    "a large shark" "a little shark" "a school of sharks"
# time_group
# afternoon              NaN              NaN                  NaN
# morning                NaN              NaN                  NaN
# night                  0.0              0.0                  0.0
#
#                                                                  \
# Species    "a small shark" "a very large shark" "a young shark"
# time_group
# afternoon              0.0                  NaN             0.0
# morning                0.0                  NaN             NaN
# night                  0.0                  0.0             NaN
#
#                                                            \
# Species    "black tipped" shark "gray shark" "grey shark"
# time_group
# afternoon                   NaN          NaN          NaN
# morning                     NaN          NaN          NaN
# night                       0.0          0.0          0.0
#
#                                                                             \
# Species    "grey-colored shark" "juvenile shark" "reef shark" "sand shark"
# time_group
# afternoon                   NaN              NaN          NaN          0.0
# morning                     NaN              0.0          0.0          0.0
# night                       0.0              NaN          NaN          0.0
#
#                                                                                \
# Species    "sand" shark "sandshark" "small brown-colored shark" "small shark"
# time_group
# afternoon           NaN         NaN                         NaN           0.0
# morning             0.0         NaN                         NaN           NaN
# night               0.0         0.0                         0.0           0.0
#
#                                                                                \
# Species    "small sharks" "whiptail shark" (thresher shark?) "whitetip shark"
# time_group
# afternoon             NaN                                NaN              0.0
# morning               NaN                                NaN              NaN
# night                 0.0                                0.0              NaN
#
#                                                                             \
# Species    +3' shark .5 m shark 0.7 m [2.5'] sand shark 0.7 m [2.5'] shark
# time_group
# afternoon        NaN        NaN                     NaN                NaN
# morning          0.0        NaN                     NaN                NaN
# night            NaN        0.0                     0.0                0.0
#
#                                                                \
# Species    0.9 m  [3'] shark 0.9 m  to 1.2 m [3' to 4'] shark
# time_group
# afternoon                0.0                              0.0
# morning                  NaN                              NaN
# night                    NaN                              NaN
#
#                                                \
# Species    0.9 m [3']  shark 0.9 m [3'] shark
# time_group
# afternoon                NaN              0.0
# morning                  NaN              0.0
# night                    0.0              0.0
#
#                                                                     \
# Species    0.9 m [3'] shark,  probably a blacktip or spinner shark
# time_group
# afternoon                                                 0.0
# morning                                                   NaN
# night                                                     NaN
#
#                                             \
# Species    0.9 m to 1.2 m [3' to 4'] shark
# time_group
# afternoon                              0.0
# morning                                0.0
# night                                  NaN
#
#                                                                                 \
# Species    0.9 m to 1.2 m [3' to 4'] shark; Tooth fragment recovered from hand
# time_group
# afternoon                                                 0.0
# morning                                                   NaN
# night                                                     NaN
#
#                                                   \
# Species    0.9 m to 1.2 m [3' to 4'] white shark
# time_group
# afternoon                                    0.0
# morning                                      NaN
# night                                        NaN
#
#                                                        \
# Species    0.9 m to 1.5 m [3' to 5'] shark 1 m  shark
# time_group
# afternoon                              NaN        0.0
# morning                                NaN        NaN
# night                                  0.0        NaN
#
#                                                                     \
# Species    1 m "grey-colored" shark 1 m hammerhead shark 1 m shark
# time_group
# afternoon                       0.0                  NaN       0.0
# morning                         NaN                  NaN       0.0
# night                           NaN                  0.0       0.0
#
#                                                     \
# Species    1 m shark, possibly whitetip reef shark
# time_group
# afternoon                                      NaN
# morning                                        0.0
# night                                          NaN
#
#                                                                   \
# Species    1' to 2' hammerhead or bonnethed shark 1' to 2' shark
# time_group
# afternoon                                     0.0            0.0
# morning                                       NaN            NaN
# night                                         NaN            NaN
#
#                                                      \
# Species    1' to 4' shark 1+ m shark 1,100-lb shark
# time_group
# afternoon             NaN        NaN            NaN
# morning               NaN        0.0            0.0
# night                 0.0        NaN            NaN
#
#                                                                    \
# Species    1,5 m [5'] Caribbean reef shark (Carcharhinus  perezi)
# time_group
# afternoon                                                 0.0
# morning                                                   NaN
# night                                                     NaN
#
#                                                               \
# Species    1.2 m  [4'] shark 1.2 m [4'] "grey-colored shark"
# time_group
# afternoon                0.0                             0.0
# morning                  NaN                             NaN
# night                    0.0                             NaN
#
#                                                                            \
# Species    1.2 m [4'] blacktip or sandbar shark 1.2 m [4'] blacktip shark
# time_group
# afternoon                                   NaN                       0.0
# morning                                     NaN                       NaN
# night                                       0.0                       NaN
#
#                                                          \
# Species    1.2 m [4'] bull shark 1.2 m [4'] dusky shark
# time_group
# afternoon                    0.0                    0.0
# morning                      0.0                    NaN
# night                        NaN                    NaN
#
#                                                          \
# Species    1.2 m [4'] hammerhead shark 1.2 m [4'] shark
# time_group
# afternoon                          NaN              0.0
# morning                            0.0              0.0
# night                              NaN              0.0
#
#                                                                        \
# Species    1.2 m [4'] shark (spinner shark?) 1.2 m [4'] spinner shark
# time_group
# afternoon                                NaN                      NaN
# morning                                  0.0                      0.0
# night                                    NaN                      NaN
#
#                                                \
# Species    1.2 m [4'], possibly  larger shark
# time_group
# afternoon                                 NaN
# morning                                   0.0
# night                                     NaN
#
#                                               \
# Species    1.2 m to 1.5 m [4' to 5']   shark
# time_group
# afternoon                                NaN
# morning                                  0.0
# night                                    NaN
#
#                                                    \
# Species    1.2 m to 1.5 m [4' to 5'] "reef shark"
# time_group
# afternoon                                     NaN
# morning                                       NaN
# night                                         0.0
#
#                                                                    \
# Species    1.2 m to 1.5 m [4' to 5'] bull, sandbar or dusky shark
# time_group
# afternoon                                                 0.0
# morning                                                   NaN
# night                                                     NaN
#
#                                                        \
# Species    1.2 m to 1.5 m [4' to 5'] hammerhead shark
# time_group
# afternoon                                         0.0
# morning                                           NaN
# night                                             NaN
#
#                                             \
# Species    1.2 m to 1.5 m [4' to 5'] shark
# time_group
# afternoon                              0.0
# morning                                0.0
# night                                  0.0
#
#                                                                    \
# Species    1.2 m to 1.5 m [4' to 5'] shark, possibly a bull shark
# time_group
# afternoon                                                 0.0
# morning                                                   NaN
# night                                                     NaN
#
#                                                                               \
# Species    1.2 m to 1.5 m [4.5' to 5'] shark 1.2 m to 1.8 m [4' to 6'] shark
# time_group
# afternoon                                NaN                             NaN
# morning                                  NaN                             0.0
# night                                    0.0                             NaN
#
#                                                              \
# Species    1.2 m to 1.8 m [4' to 6'] shark observed in area
# time_group
# afternoon                                               NaN
# morning                                                 NaN
# night                                                   0.0
#
#                                                              \
# Species    1.3 m [4'3"] shark 1.3 to 1.6 m shark 1.3m shark
# time_group
# afternoon                 0.0                NaN        NaN
# morning                   NaN                0.0        0.0
# night                     NaN                NaN        NaN
#
#                                                                              \
# Species    1.4 m [4'6"] blacktip shark 1.4 m [4.5'] shark 1.5 m [5']  shark
# time_group
# afternoon                          NaN                NaN               NaN
# morning                            NaN                NaN               NaN
# night                              0.0                0.0               0.0
#
#                                                                       \
# Species    1.5 m [5'] "whaler shark" 1.5 m [5'] Caribbean reef shark
# time_group
# afternoon                        NaN                             NaN
# morning                          0.0                             NaN
# night                            NaN                             0.0
#
#                                                              \
# Species    1.5 m [5'] blacktip shark 1.5 m [5'] dusky shark
# time_group
# afternoon                        NaN                    NaN
# morning                          0.0                    0.0
# night                            NaN                    NaN
#
#                                                          \
# Species    1.5 m [5'] hammerhead shark 1.5 m [5'] shark
# time_group
# afternoon                          NaN              0.0
# morning                            NaN              0.0
# night                              0.0              0.0
#
#                                                                            \
# Species    1.5 m [5'] shark, either a bronze whaler or a grey nurse shark
# time_group
# afternoon                                                 0.0
# morning                                                   NaN
# night                                                     NaN
#
#                                                   \
# Species    1.5 m [5'] shark, probable bull shark
# time_group
# afternoon                                    NaN
# morning                                      NaN
# night                                        0.0
#
#                                                                          \
# Species    1.5 m [5'] white shark or sevengill shark 1.5 m copper shark
# time_group
# afternoon                                        NaN                NaN
# morning                                          NaN                0.0
# night                                            0.0                NaN
#
#                                                                                \
# Species    1.5 m grey reef shark 1.5 m shark 1.5 m to 1.8 m  [5' to 6'] shark
# time_group
# afternoon                    NaN         0.0                              NaN
# morning                      NaN         0.0                              0.0
# night                        0.0         0.0                              NaN
#
#                                                       \
# Species    1.5 m to 1.8 m [5' to 6']  blacktip shark
# time_group
# afternoon                                        NaN
# morning                                          NaN
# night                                            0.0
#
#                                                     \
# Species    1.5 m to 1.8 m [5' to 6'] Zambesi shark
# time_group
# afternoon                                      NaN
# morning                                        0.0
# night                                          NaN
#
#                                                     \
# Species    1.5 m to 1.8 m [5' to 6'] sandbar shark
# time_group
# afternoon                                      0.0
# morning                                        NaN
# night                                          NaN
#
#                                                                              \
# Species    1.5 m to 1.8 m [5' to 6'] shark 1.5 m to 1.8 m [5' to 6'] sharks
# time_group
# afternoon                              0.0                              NaN
# morning                                NaN                              NaN
# night                                  0.0                              0.0
#
#                                                          \
# Species    1.5 m to 1.8 m [5' to 6'] “spear-eye” shark
# time_group
# afternoon                                           NaN
# morning                                             0.0
# night                                               NaN
#
#                                            \
# Species    1.5 m to 1.8m [5' to 6'] shark
# time_group
# afternoon                             NaN
# morning                               0.0
# night                                 NaN
#
#                                                              \
# Species    1.5 m to 2 m [5' to 6.75'] Caribbean reef shark
# time_group
# afternoon                                               NaN
# morning                                                 NaN
# night                                                   0.0
#
#                                                                 \
# Species    1.5 m to 2 m [5' to 6.75'] shark 1.5 m to 2 m shark
# time_group
# afternoon                               0.0                0.0
# morning                                 NaN                NaN
# night                                   NaN                NaN
#
#                                              \
# Species    1.5 m to 2.1 m  [5' to 7'] shark
# time_group
# afternoon                               0.0
# morning                                 NaN
# night                                   NaN
#
#                                                                    \
# Species    1.5 m to 2.1 m [5' to 7'] shark, possibly a mako shark
# time_group
# afternoon                                                 NaN
# morning                                                   NaN
# night                                                     0.0
#
#                                                              \
# Species    1.5 m white-tipped reef shark 1.5 m, 45-kg shark
# time_group
# afternoon                            NaN                NaN
# morning                              NaN                0.0
# night                                0.0                NaN
#
#                                                                          \
# Species    1.5 to 1.8 m [5' to 6'] shark 1.5 to 2 m [5' to 6.75'] shark
# time_group
# afternoon                            NaN                            NaN
# morning                              0.0                            NaN
# night                                NaN                            0.0
#
#                                                                      \
# Species    1.5 to 2 m shark 1.5 to 2.5 m [5' to 8.25'] copper shark
# time_group
# afternoon               0.0                                     NaN
# morning                 NaN                                     NaN
# night                   NaN                                     0.0
#
#                                                                         \
# Species    1.5' to 2' shark 1.6 m shark 1.7 m [5.5'] shark 1.7 m shark
# time_group
# afternoon               0.0         NaN                0.0         NaN
# morning                 NaN         0.0                NaN         NaN
# night                   NaN         NaN                NaN         0.0
#
#                                                          \
# Species    1.8 m [6']  shark 1.8 m [6'] "cocktail shark
# time_group
# afternoon                0.0                        NaN
# morning                  NaN                        NaN
# night                    NaN                        0.0
#
#                                                                      \
# Species    1.8 m [6'] Caribbean reef shark 1.8 m [6'] Zambezi shark
# time_group
# afternoon                              NaN                      NaN
# morning                                NaN                      0.0
# night                                  0.0                      NaN
#
#                                       \
# Species    1.8 m [6'] blacktip shark
# time_group
# afternoon                        0.0
# morning                          0.0
# night                            0.0
#
#                                                               \
# Species    1.8 m [6'] blacktip shark or Caribbean reef shark
# time_group
# afternoon                                                0.0
# morning                                                  NaN
# night                                                    NaN
#
#                                                                              \
# Species    1.8 m [6'] blacktip shark or spinner shark 1.8 m [6'] bull shark
# time_group
# afternoon                                         NaN                   NaN
# morning                                           NaN                   0.0
# night                                             0.0                   NaN
#
#                                                        \
# Species    1.8 m [6'] carpet shark 1.8 m [6'] dogfish
# time_group
# afternoon                      NaN                NaN
# morning                        NaN                NaN
# night                          0.0                0.0
#
#                                                                      \
# Species    1.8 m [6'] grey reef shark 1.8 m [6'] grey-colored shark
# time_group
# afternoon                         NaN                           NaN
# morning                           NaN                           NaN
# night                             0.0                           0.0
#
#                                                                                       \
# Species    1.8 m [6'] reef shark - or a 2.1 m to 2.4 m [7' to 8'] grey-colored shark
# time_group
# afternoon                                                 NaN
# morning                                                   0.0
# night                                                     NaN
#
#                                                                           \
# Species    1.8 m [6'] sandtiger shark 1.8 m [6'] shark 1.8 m [6'] shark
# time_group
# afternoon                         NaN              0.0               0.0
# morning                           NaN              0.0               NaN
# night                             0.0              0.0               0.0
#
#                                                   \
# Species    1.8 m [6'] shark, possibly a blacktip
# time_group
# afternoon                                    0.0
# morning                                      NaN
# night                                        NaN
#
#                                                             \
# Species    1.8 m [6'] shark, species identity questionable
# time_group
# afternoon                                              NaN
# morning                                                NaN
# night                                                  0.0
#
#                                                                       \
# Species    1.8 m [6'] white shark 1.8 m [6'], 136-kg [300-lb] shark
# time_group
# afternoon                     0.0                                0.0
# morning                       NaN                                NaN
# night                         NaN                                NaN
#
#                                                                  \
# Species    1.8 m [6'], 180-lb shark 1.8 m blacktip "reef" shark
# time_group
# afternoon                       NaN                         NaN
# morning                         NaN                         NaN
# night                           0.0                         0.0
#
#                                                            \
# Species    1.8 m grey shark 1.8 m shark 1.8 m silky shark
# time_group
# afternoon               0.0         0.0               0.0
# morning                 NaN         0.0               NaN
# night                   NaN         0.0               NaN
#
#                                             \
# Species    1.8 m to 2 m [6' to 6'9"] shark
# time_group
# afternoon                              0.0
# morning                                NaN
# night                                  NaN
#
#                                                        \
# Species    1.8 m to 2.1 m [6' to 7'] hammerhead shark
# time_group
# afternoon                                         0.0
# morning                                           NaN
# night                                             NaN
#
#                                             \
# Species    1.8 m to 2.1 m [6' to 7'] shark
# time_group
# afternoon                              0.0
# morning                                0.0
# night                                  NaN
#
#                                                                 \
# Species    1.8 m to 2.1 m [6' to 7'] spinner or blacktip shark
# time_group
# afternoon                                                 0.0
# morning                                                   NaN
# night                                                     NaN
#
#                                                              \
# Species    1.8 m to 2.1 m [6' to 7']  Caribbean Reef Shark
# time_group
# afternoon                                               NaN
# morning                                                 0.0
# night                                                   NaN
#
#                                              \
# Species    1.8 m to 2.4 m  [6' to 8'] shark
# time_group
# afternoon                               NaN
# morning                                 NaN
# night                                   0.0
#
#                                                            \
# Species    1.8 m to 2.4 m [6' to 8'] "black finned shark"
# time_group
# afternoon                                             NaN
# morning                                               NaN
# night                                                 0.0
#
#                                                        \
# Species    1.8 m to 2.4 m [6' to 8'] hammerhead shark
# time_group
# afternoon                                         0.0
# morning                                           NaN
# night                                             0.0
#
#                                             \
# Species    1.8 m to 2.4 m [6' to 8'] shark
# time_group
# afternoon                              0.0
# morning                                0.0
# night                                  0.0
#
#                                                                         \
# Species    1.8 m to 2.4 m [6' to 8'] shark, tooth fragments recovered
# time_group
# afternoon                                                 NaN
# morning                                                   NaN
# night                                                     0.0
#
#                                                                                 \
# Species    1.8 m to 2.4 m [6' to 8'] sharks, most were oceanic whitetip sharks
# time_group
# afternoon                                                 NaN
# morning                                                   0.0
# night                                                     NaN
#
#                                                   \
# Species    1.8 m to 2.4 m [6' to 8'] white shark
# time_group
# afternoon                                    NaN
# morning                                      0.0
# night                                        NaN
#
#                                                             \
# Species    1.8 m to 2.7 m [6' to 9'] shark 1.8 metre shark
# time_group
# afternoon                              NaN             0.0
# morning                                0.0             NaN
# night                                  NaN             NaN
#
#                                                                        \
# Species    1.8 to 2 m C. albimarginatus 1.8 to 2.1 m [6' to 7'] shark
# time_group
# afternoon                           NaN                           0.0
# morning                             0.0                           NaN
# night                               NaN                           NaN
#
#                                                           \
# Species    1.8 to 2.4 m [6' to 8'] shark 1.8m bull shark
# time_group
# afternoon                            0.0             NaN
# morning                              NaN             0.0
# night                                NaN             NaN
#
#                                                               \
# Species    1.9 m [6.5'] bull shark 10' shark 10' tiger shark
# time_group
# afternoon                      0.0       0.0             0.0
# morning                        NaN       NaN             NaN
# night                          NaN       0.0             0.0
#
#                                                                             \
# Species    10' to 12' Galapagos shark 10' to 12' shark 10'-12' tiger shark
# time_group
# afternoon                         0.0              NaN                 NaN
# morning                           NaN              0.0                 0.0
# night                             NaN              0.0                 NaN
#
#                                                                               \
# Species    100-kg [221-lb] dead blue shark 100-lb shark 106 cm [3.5']  shark
# time_group
# afternoon                              NaN          NaN                  NaN
# morning                                NaN          NaN                  0.0
# night                                  0.0          0.0                  NaN
#
#                                                                            \
# Species    12' sandtiger shark 12' shark 12' tiger shark 12' to 14' shark
# time_group
# afternoon                  NaN       0.0             NaN              NaN
# morning                    NaN       0.0             NaN              0.0
# night                      0.0       0.0             0.0              0.0
#
#                                                                               \
# Species    12' to 14' white shark 12' to 18' shark 12' white shark 13' shark
# time_group
# afternoon                     NaN              NaN             NaN       NaN
# morning                       0.0              0.0             NaN       0.0
# night                         NaN              NaN             0.0       0.0
#
#                                                                           \
# Species    13', 400-lb thresher shark 13'10" shark 136-kg [300-lb] shark
# time_group
# afternoon                         NaN          0.0                   0.0
# morning                           NaN          NaN                   NaN
# night                             0.0          NaN                   NaN
#
#                                                                              \
# Species    14' shark 14' to 16' white shark 14' to 18'shark 14' white shark
# time_group
# afternoon        0.0                    0.0             NaN             NaN
# morning          NaN                    NaN             0.0             0.0
# night            0.0                    NaN             NaN             NaN
#
#                                                                               \
# Species    15 cm to 20 cm [6" to 8"] bite diameter just below left knee  15'
# time_group
# afternoon                                                 0.0            NaN
# morning                                                   NaN            NaN
# night                                                     NaN            0.0
#
#                                                                          \
# Species    15' shark 15* to 24" dog shark 150-lb shark 16' 800-lb shark
# time_group
# afternoon        0.0                  NaN          NaN              NaN
# morning          0.0                  NaN          0.0              NaN
# night            0.0                  0.0          NaN              0.0
#
#                                                                           \
# Species    16' shark 16' white shark 17' white shark 170-kg, 2.8 m shark
# time_group
# afternoon        NaN             NaN             NaN                 NaN
# morning          NaN             NaN             NaN                 0.0
# night            0.0             0.0             0.0                 NaN
#
#                                                                              \
# Species    18" - 23" Horn shark 18" to 24" shark 18" to 36" shark 18' shark
# time_group
# afternoon                   0.0              0.0              NaN       NaN
# morning                     NaN              0.0              NaN       0.0
# night                       NaN              0.0              0.0       0.0
#
#                                                                 \
# Species    18' white shark 18-foot shark 193-lb shark 1m shark
# time_group
# afternoon              NaN           NaN          NaN      NaN
# morning                0.0           NaN          NaN      0.0
# night                  NaN           0.0          0.0      0.0
#
#                                                        \
# Species    1m shark species unknown 1m to 1.2 m shark
# time_group
# afternoon                       NaN               NaN
# morning                         NaN               0.0
# night                           0.0               NaN
#
#                                                                            \
# Species    2 days later a 600-lb shark was caught 100 yards from the site
# time_group
# afternoon                                                 NaN
# morning                                                   NaN
# night                                                     0.0
#
#                                                                                           \
# Species    2 m  "yellow belly" captive shark. Shark destroyed by aquarium staff next day
# time_group
# afternoon                                                 NaN
# morning                                                   NaN
# night                                                     0.0
#
#                                                                         \
# Species    2 m [6'9"] Zambesi shark 2 m [6'9"] shark 2 m [6'9"] shark
# time_group
# afternoon                       NaN              0.0               NaN
# morning                         NaN              0.0               NaN
# night                           0.0              0.0               0.0
#
#                                                                          \
# Species    2 m [6'9"], 87.5-kg [193-lb]  shark 2 m [6.75'] copper shark
# time_group
# ...
# Species    White shark, according to witnesses
# time_group
# afternoon                                  0.0
# morning                                    NaN
# night                                      0.0
#
#                                                                 \
# Species    White shark, based on 2 teeth retrieved from rudder
# time_group
# afternoon                                                 NaN
# morning                                                   NaN
# night                                                     0.0
#
#                                                                         \
# Species    White shark, based on bite pattern White shark, female, 14'
# time_group
# afternoon                                 NaN                      NaN
# morning                                   NaN                      NaN
# night                                     0.0                      0.0
#
#                                                      \
# Species    White shark, identification by K. Nakaya
# time_group
# afternoon                                       0.0
# morning                                         NaN
# night                                           NaN
#
#                                                                     \
# Species    White shark, identified by tooth fragments in surfboard
# time_group
# afternoon                                                 0.0
# morning                                                   NaN
# night                                                     NaN
#
#                                                                            \
# Species    White shark, identified by tooth pattern White shark, juvenile
# time_group
# afternoon                                       0.0                   NaN
# morning                                         NaN                   0.0
# night                                           NaN                   NaN
#
#                                                                      \
# Species    White shark, species identity confirmed by tooth pattern
# time_group
# afternoon                                                 NaN
# morning                                                   0.0
# night                                                     NaN
#
#                                                                            \
# Species    White shark,4.6 m [15']  White shark? White sharks White xhark
# time_group
# afternoon                       0.0          0.0          NaN         NaN
# morning                         NaN          NaN          NaN         0.0
# night                           NaN          0.0          0.0         NaN
#
#                                                         \
# Species    Whitetip reef shark Whitetip reef shark, 1m
# time_group
# afternoon                  NaN                     NaN
# morning                    0.0                     NaN
# night                      NaN                     0.0
#
#                                                                         \
# Species    Whitetip reef shark, 4' to 6' Whtietip reef shark Wobbegong
# time_group
# afternoon                            0.0                 NaN       NaN
# morning                              NaN                 NaN       NaN
# night                                NaN                 0.0       0.0
#
#                                                                   \
# Species    Wobbegong shark Wobbegong shark  Wobbegong shark, 1 m
# time_group
# afternoon              0.0              NaN                  NaN
# morning                0.0              NaN                  0.0
# night                  0.0              0.0                  NaN
#
#                                                                        \
# Species    Wobbegong shark, 1.2 m [4']  Wobbegong shark, 1.2 m [4'] k
# time_group
# afternoon                           NaN                           NaN
# morning                             0.0                           0.0
# night                               NaN                           NaN
#
#                                                                           \
# Species    Wobbegong shark, 1.4 m [4'6"]  Wobbegong shark, 1.4 m [4.6']
# time_group
# afternoon                             NaN                            NaN
# morning                               0.0                            NaN
# night                                 NaN                            0.0
#
#                                                                \
# Species    Wobbegong shark, 1.5 m [5']  Wobbegong shark, 1.6m
# time_group
# afternoon                           NaN                   NaN
# morning                             0.0                   0.0
# night                               NaN                   NaN
#
#                                                              \
# Species    Wobbegong shark, 1.8 m [6']  Wobbegong shark, 1m
# time_group
# afternoon                           NaN                 NaN
# morning                             NaN                 NaN
# night                               0.0                 0.0
#
#                                                                            \
# Species    Wobbegong shark, 2 m  Wobbegong shark, 2m Wobbegong shark, 3'
# time_group
# afternoon                    0.0                 NaN                  NaN
# morning                      NaN                 NaN                  NaN
# night                        NaN                 0.0                  0.0
#
#                                                                           \
# Species    Wobbegong shark, 4' Wobbegong shark, 4'  Wobbegong shark, 5'
# time_group
# afternoon                  NaN                  NaN                  NaN
# morning                    0.0                  NaN                  NaN
# night                      NaN                  0.0                  0.0
#
#                                                       \
# Species    Wobbegong shark, 6' Wobbegong shark, 60cm
# time_group
# afternoon                  NaN                   NaN
# morning                    NaN                   NaN
# night                      0.0                   0.0
#
#                                                                                   \
# Species    Wobbegong shark, O. barbatus,  1.8 m [6'], identified by G.P. Whitley
# time_group
# afternoon                                                 NaN
# morning                                                   NaN
# night                                                     0.0
#
#                                                                     \
# Species    Wobbegong shark? Wobbegong, 2m Wobbegongs Zambesi shark
# time_group
# afternoon               NaN           NaN        NaN           0.0
# morning                 0.0           NaN        NaN           0.0
# night                   0.0           0.0        0.0           0.0
#
#                                                                     \
# Species    Zambesi shark, 1.2 m [4']  Zambesi shark, 1.7 m [5.5']
# time_group
# afternoon                         NaN                          0.0
# morning                           0.0                          NaN
# night                             NaN                          NaN
#
#                                                                   \
# Species    Zambesi shark, 1.8 m [6']  Zambesi shark, 2 m [6'9"]
# time_group
# afternoon                         0.0                        0.0
# morning                           NaN                        NaN
# night                             NaN                        NaN
#
#                                                                   \
# Species    Zambesi shark, 2m  Zambesi shark, 4'9" Zambesi shark?
# time_group
# afternoon                 0.0                 NaN            NaN
# morning                   NaN                 NaN            NaN
# night                     NaN                 0.0            0.0
#
#                                                                  \
# Species    Zambezi shark (tooth fragments recovered) [4' to 5']
# time_group
# afternoon                                        NaN        0.0
# morning                                          0.0        NaN
# night                                            NaN        NaN
#
#                                                                        \
# Species    [4.5' to 5'] shark a "small slim brown shark" a sand shark
# time_group
# afternoon                 0.0                        NaN          NaN
# morning                   NaN                        0.0          NaN
# night                     NaN                        NaN          0.0
#
#                                                                            \
# Species    a school of sharks a small hammerhead shark a small reef shark
# time_group
# afternoon                 NaN                      0.0                NaN
# morning                   NaN                      NaN                0.0
# night                     0.0                      NaN                NaN
#
#                                                                               \
# Species    a small shark a small shark' blacktip or spinner shark bull shark
# time_group
# afternoon            0.0            NaN                       0.0        0.0
# morning              0.0            NaN                       0.0        0.0
# night                0.0            0.0                       NaN        NaN
#
#                                                                       \
# Species    dogfish dogfish shark juvenile shark juvenile white shark
# time_group
# afternoon      NaN           NaN            0.0                  NaN
# morning        0.0           0.0            NaN                  0.0
# night          NaN           NaN            NaN                  NaN
#
#                                                                              \
# Species    nurse shark possibly a bronze whaler shark possibly a bull shark
# time_group
# afternoon          NaN                            NaN                   NaN
# morning            NaN                            0.0                   NaN
# night              0.0                            NaN                   0.0
#
#                                                                    \
# Species    reef shark reef shark, 1.5m reef shark, 1m reef shark?
# time_group
# afternoon         NaN              0.0            NaN         0.0
# morning           NaN              NaN            0.0         NaN
# night             0.0              NaN            NaN         0.0
#
#                                                     \
# Species    said to involve 2.5 m hammerhead sharks
# time_group
# afternoon                                      NaN
# morning                                        NaN
# night                                          0.0
#
#                                           \
# Species    said to involve a tiger shark
# time_group
# afternoon                            NaN
# morning                              NaN
# night                                0.0
#
#                                                                  \
# Species    said to involve an oceanic whitetip shark sand shark
# time_group
# afternoon                                        0.0        0.0
# morning                                          NaN        NaN
# night                                            NaN        NaN
#
#                                                                       \
# Species    sandtiger shark shark involvement not confirmed shark pup
# time_group
# afternoon              NaN                             NaN       0.0
# morning                NaN                             NaN       NaN
# night                  0.0                             0.0       NaN
#
#                                                                         \
# Species    small blacktip shark small blacktip shark? small blue shark
# time_group
# afternoon                   0.0                   NaN              0.0
# morning                     NaN                   0.0              0.0
# night                       0.0                   NaN              NaN
#
#                                                                       \
# Species    small carpet shark small catsharks small hammerhead shark
# time_group
# afternoon                 NaN             NaN                    NaN
# morning                   NaN             NaN                    NaN
# night                     0.0             0.0                    0.0
#
#                                                                      \
# Species    small nurse shark small shark small sharks small sharks'
# time_group
# afternoon                NaN         0.0          NaN           NaN
# morning                  NaN         0.0          NaN           NaN
# night                    0.0         0.0          0.0           0.0
#
#                                                                           \
# Species    unknown, possibly a white shark whaler shark white shark
# time_group
# afternoon                              NaN          NaN         NaN  NaN
# morning                                NaN          NaN         NaN  0.0
# night                                  0.0          0.0         0.0  NaN
#
#
# Species    “small brown shark”
# time_group
# afternoon                  NaN
# morning                    0.0
# night                      NaN
